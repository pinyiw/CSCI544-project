# %%
import random
import json
import openai
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from summac.model_summac import SummaCZS
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
acos_pred_only = "yelp-acos-_ab50qdWOk0DdB6XOrBitw-200.jsonl"
acos_pred_category = "yelp-acos-_ab50qdWOk0DdB6XOrBitw-200-category-groups.json"
acos_pred_aspect = "yelp-acos-_ab50qdWOk0DdB6XOrBitw-200-aspect-groups.json"

review_sample = "yelp-acos-100-sampled-rest-reviews.json"

openai.api_key = ""

# %% [markdown]
# ### Read in quads from JSON

# %%
# Read in 200 reviews each with ACOS predictions - Each line is a JSON dictionary
reviews_acos = []
with open(acos_pred_only, "r") as f:
    for line in f:
        review = json.loads(line)
        reviews_acos.append(review)

# %%
# Read in reviews grouped by category, 5 category groups were chosen
# len(reviews_acos_category) = 5
# each category group has three items: group_name, group_size, group
reviews_acos_category = {}
with open(acos_pred_category, "r") as f:
    reviews_acos_category = json.load(f)

# %%
# 5 Categories
print("Sorted by categories")
categories = []
for i in range(0, len(reviews_acos_category)):
    categories.append(reviews_acos_category[i]['group_name'])
    
for i in range(0, len(reviews_acos_category)):
    print(reviews_acos_category[i]['group_name'] + ":", reviews_acos_category[i]['group_size'], "reviews")
# Out:
# Sorted by categories
# QUALITY: 532 reviews
# GENERAL: 244 reviews
# STYLE_OPTIONS: 113 reviews
# SERVICE: 52 reviews
# PRICES: 22 reviews

# %%
categories
# Out:
# ['QUALITY', 'GENERAL', 'STYLE_OPTIONS', 'SERVICE', 'PRICES']

# %%
# Read in reviews grouped by aspect, 7 aspects were chosen
# len(reviews_acos_aspect) = 7
# each aspect has three items: group_name, group_size, group
reviews_acos_aspect = {}
with open(acos_pred_aspect, "r") as f:
    reviews_acos_aspect = json.load(f)

# %%
# 7 Aspects
print("Sorted by aspects")
aspects = []
for i in range(0, len(reviews_acos_aspect)):
    aspects.append(reviews_acos_aspect[i]['group_name'])

for i in range(0, len(reviews_acos_aspect)):
    print(reviews_acos_aspect[i]['group_name'] + ":", reviews_acos_aspect[i]['group_size'], "reviews")
# Out:
# Sorted by aspects
# oysters: 54 reviews
# service: 45 reviews
# chargrilled oysters: 43 reviews
# food: 41 reviews
# Acme: 29 reviews
# place: 24 reviews
# gumbo: 22 reviews

# %%
aspects
# Out:
# ['oysters', 'service', 'chargrilled oysters', 'food', 'Acme', 'place', 'gumbo']

# %% [markdown]
# ### Use GPT to turn these quads into summary about that specific aspect for 1 restaurant
# #### Pass just quads (Grouped by Categories) to gpt/davinci to generate summary

# %%
categories_output = []

# %%
# Compile all acos quadruples for each category/aspect
# returns a list of acos quadruples for said aspect
def compile_acos(group_index, review_acos_dictionary):
    acos_quads = []
    group_name = review_acos_dictionary[group_index]['group_name']
    for i in range(review_acos_dictionary[group_index]['group_size']):        
        reviews = review_acos_dictionary[group_index]['group'][i]['acos_preds']
        for j in range(len(reviews)):
            if(reviews[j]['category'] == group_name):
                acos_quads.append(reviews[j])
    return acos_quads

# Function to generate a prompt
def generate_prompt(group_name, acos_quads, max_quads):
    
    # Format the acos quadruples into a string
    def acos2str(acos_quads):
        formatted_acos = ""
        for i, item in enumerate(acos_quads):
            aspect = ' '.join(item['aspect']) if isinstance(item['aspect'], (list, tuple)) else item['aspect']
            opinion = ' '.join(item['opinion']) if isinstance(item['opinion'], (list, tuple)) else item['opinion']
            #category = item['category']
            sentiment = item['sentiment']
            #formatted_acos += f"{i+1}. Aspect: {aspect}, Category: {category}, Opinion: {opinion}, Sentiment: {sentiment}\n"
            formatted_acos += f"{i+1}. Aspect: {aspect}, Opinion: {opinion}, Sentiment: {sentiment}\n"
        return formatted_acos.strip()
    
    acos_quads = acos_quads[:max_quads]
    prompt = f'Summarize the following restaurant reviews with at most 5 sentences. Instead of reviews, you are provided with aspect-category-opinion-sentiment quadruples. The summarization should only be about "{group_name}". '
    formatted_acos_string = acos2str(acos_quads)
    
    prompt = prompt + formatted_acos_string
    
    return prompt

def generate_summary_category(group_index):
    review2acos = compile_acos(group_index, reviews_acos_category)

    openai_model = "text-davinci-003"
    group_name = categories[group_index]

    prompt = generate_prompt(group_name, review2acos, 150)

    resp = openai.Completion.create(
        model = openai_model,
        prompt = prompt,
        temperature = 0,
        max_tokens = 1000
    )

    summary_str = resp['choices'][0]['text'].replace('\n', '')
    temp_tuple = (group_name, summary_str)
    
    return temp_tuple

# %%
#review2acos = compile_acos(0, reviews_acos_category)
#group_name = categories[0]
#prompt = generate_prompt(group_name, review2acos, 150)
#print(prompt)

# %%
for i in range(len(reviews_acos_category)):
    temp_tuple = generate_summary_category(i)
    categories_output.append(temp_tuple)
#print(categories_output)

# %%
for category, text in categories_output:
    print(f"{category}:\n{text}\n")

# %% [markdown]
# #### Pass just quads (Grouped by Aspect) to gpt/davinci to generate summary

# %%
aspect_output = []

# %%
# Compile all acos quadruples for each category/aspect
# returns a list of acos quadruples for said aspect
def compile_acos(group_index, review_acos_dictionary):
    acos_quads = []
    group_name = review_acos_dictionary[group_index]['group_name']
    for i in range(review_acos_dictionary[group_index]['group_size']):        
        reviews = review_acos_dictionary[group_index]['group'][i]['acos_preds']
        for j in range(len(reviews)):
            if reviews[j]['aspect'] is not None and group_name in reviews[j]['aspect']:
                acos_quads.append(reviews[j])
    return acos_quads

# Function to generate a prompt
def generate_prompt(group_name, acos_quads, max_quads):
    
    # Format the acos quadruples into a string
    def acos2str(acos_quads):
        formatted_acos = ""
        for i, item in enumerate(acos_quads):
            #aspect = ' '.join(item['aspect']) if isinstance(item['aspect'], (list, tuple)) else item['aspect']
            opinion = ' '.join(item['opinion']) if isinstance(item['opinion'], (list, tuple)) else item['opinion']
            category = item['category']
            sentiment = item['sentiment']
            #formatted_acos += f"{i+1}. Aspect: {aspect}, Category: {category}, Opinion: {opinion}, Sentiment: {sentiment}\n"
            formatted_acos += f"{i+1}. Category: {category}, Opinion: {opinion}, Sentiment: {sentiment}\n"
        return formatted_acos.strip()
    
    acos_quads = acos_quads[:max_quads]
    prompt = f'Summarize the following restaurant reviews with at most 5 sentences. Instead of reviews, you are provided with aspect-category-opinion-sentiment quadruples. The summarization should only be about "{group_name}". '
    formatted_acos_string = acos2str(acos_quads)
    
    prompt = prompt + formatted_acos_string
    
    return prompt

def generate_summary_aspects(group_index):
    review2acos = compile_acos(group_index, reviews_acos_aspect)

    openai_model = "text-davinci-003"
    group_name = aspects[group_index]

    prompt = generate_prompt(group_name, review2acos, 150)

    resp = openai.Completion.create(
        model = openai_model,
        prompt = prompt,
        temperature = 0,
        max_tokens = 1000
    )

    summary_str = resp['choices'][0]['text'].replace('\n', '')
    temp_tuple = (group_name, summary_str)
    
    return temp_tuple

# %%
for i in range(len(reviews_acos_aspect)):
    temp_tuple = generate_summary_aspects(i)
    aspect_output.append(temp_tuple)

# %%
for aspect, text in aspect_output:
    print(f"{aspect}:\n{text}\n")

# %% [markdown]
# ### Evaluation

# %%
reviews = [x['review'] for x in reviews_acos]

# %%
model_zs = SummaCZS(granularity="sentence", model_name="vitc", device="cuda") # If you have a GPU: switch to: device="cuda"

# %%
# convert review samples to list of strings
with open(review_sample, "r") as f:
    reviews_rest = json.load(f)
reviews_rest_concat = []
for restaurant in reviews_rest: 
    revs = ""
    for rev in restaurant['reviews']:
        revs += rev
    reviews_rest_concat.append(revs)

# %%
def split_and_rephrase(sum):
    sum1 = "The restaurant reviews cover a range of opinions on food quality, with many customers raving about the food. Several reviews praise the presentation of the food, and others mention specific dishes that were particularly good. There are also some negative reviews, with complaints about inconsistent quality, downsized portions, high prices, and poor service. However, overall, the majority of reviews are positive, with many customers recommending the restaurant and its food. The reviews cover a range of cuisines, including Mexican, Indian, and sushi, with some specific dishes mentioned as standouts."
    sum1_rephrased = "The presentation of the food is praised .\n Food quality is inconsistent .\n Portions are downsized .\n Prices are high .\n Service is poor .\n The restaurant and its food are recommended .\n Mexican food is good .\n Indian food is good .\n Sushi is good ."
    sum2 = "The restaurant reviews cover a variety of food types and service experiences. Some of the positive reviews include comments about the best tuna ever had, great value sushi with high quality, superb caesar salad, and the best crab cakes in town. On the other hand, some of the negative reviews mention poor customer service, poor quality pizza, and overpriced food. Additionally, some reviewers mention specific dishes they enjoyed such as the seabass on lobster risotto, honey walnut prawns, asparagus, and lobster 3 ways. Overall, there are mixed reviews, with some praising the food quality while others criticize the service and value."
    sum2_rephrased = "The tuna is the best that customers ever had .\n Sushi is of great value and high quality .\n Caesar salad is superb .\n Crab cakes are the best in town .\n Customer service is poor .\n Pizza is of poor quality .\n Food is overpriced .\n Customers enjoyed the seabass on lobster risotto .\n Customers enjoyed honey walnut prawns .\n Customers enjoyed asparagus .\n Customers enjoyed lobster 3 ways ."
    prompt = "Split and rephrase the following sentences into simple propositions: "
    input = prompt + sum1 + "\n Output: " + sum1_rephrased + "\n" + prompt + sum2 + "\n Output: " + sum2_rephrased + "\n" + prompt + sum + "\n Output: "
    # print(prompt)
    resp = openai.Completion.create(
        model="text-davinci-003",
        prompt=input,
        temperature=0,
        max_tokens=1000
    )
    pred_str = resp['choices'][0]['text']
    return pred_str

# %%
def compute_faithfulness(reviews, summary, t):
    avg_support = 0
    for sum in summary:
        support = 0
        # reviews_batch = random.sample(reviews, 20)
        for review in reviews:
            score_zs = model_zs.score([review], [sum])['scores'][0]
            # if score_zs > 0.2:
            if score_zs > t:
                support += 1
        avg_support += support

        print("summary:", sum)
        print("support:", support)
        print("=====")

    avg_support /= len(summary)
    print("faithfulness:", avg_support)
    return avg_support

# %%
def compute_factuality(reviews, summary):
    avg_topscore = 0
    for sum in summary:
        top_score = 0
        # reviews_batch = random.sample(reviews, 20)
        for review in reviews:
            score_zs = model_zs.score([review], [sum])['scores'][0]
            top_score = max(top_score, score_zs)
        avg_topscore += top_score

        print("summary:", sum)
        print("top score:", top_score)
        print("=====")

    avg_topscore /= len(summary)
    print("factuality:", avg_topscore)
    return avg_topscore

# %%
def compute_genericity(reviews, summary):
    # remove stop words and puctuations
    stop_words = set(stopwords.words('english'))
    summary_words = []
    for sum in summary:
        sum = sum.split(" ")
        sum = [word.lower() for word in sum if word not in stop_words and len(word) > 0 and word != "."]
        summary_words += sum

    avg_idf = 0
    for word in summary_words:
        count = 0
        for review in reviews:
            count += (review.find(word) != -1)
        # plus-one smoothing in case count = 0
        idf = len(reviews) / (count+1)
        avg_idf += idf

        print("word in summary:", word)
        print("count:", count)
        print("=====")

    avg_idf /= len(summary_words)
    print("genericity:", avg_idf)
    return avg_idf

# %%
summary_file = 'yelp_summary_category_review+acos'
with open(summary_file, 'r') as f:
    summary = f.read()
summary_split = split_and_rephrase(summary).split('\n')
summary_split = [x for x in summary_split if len(x) > 0]

# %%
summary_split
# Out:
# [' Oysters are of good quality .',
#  ' Bloody Marys are of good quality .',
#  ' Fresh oysters are of good quality .',
#  ' Chargrilled oysters are of good quality .',
#  ' Bread and butter is of good quality .',
#  ' Crawfish puppies are of good quality .',
#  ' Fried seafood is mediocre to horrible .',
#  ' Gumbo has too much salt .',
#  ' Staff is praised .',
#  ' Service is praised .',
#  ' Atmosphere is praised .',
#  ' Wait is worth it .',
#  ' Roscoe and Brandon are friendly .',
#  ' Restaurant is a must-visit .',
#  ' Wait can be long .',
#  ' Service can be spotty .',
#  ' Variety of style options is offered .',
#  ' 15 Dozen Club is offered .',
#  ' Soft shell crab is offered .',
#  ' 1/2 and 1/2 is offered .',
#  ' Beer on tap is offered .',
#  ' Oyster bar is offered .',
#  ' Splitting checks is offered .',
#  ' Splitting credit card payments is offered .',
#  ' Oysters are offered .',
#  ' Atmosphere is offered .',
#  ' Dress is offered .',
#  ' Reservation is offered .',
#  ' Food is offered .',
#  ' Wait times are offered .',
#  ' Grab a beer is offered .',
#  ' Sampler plate is offered .',
#  ' PO boy is offered .',
#  ' Draft beer is offered .',
#  ' Char-grilled oysters are offered .',
#  ' Crawfish is offered .',
#  " Po'boy is offered .",
#  ' Gumbo is offered .',
#  ' Local IPAs is offered .',
#  ' Bar is offered .',
#  ' Cocktails is offered .',
#  ' Lettuce is offered .',
#  ' Fried food is offered .',
#  ' Salad is offered .',
#  ' Payment is offered .',
#  ' Seat at the bar is offered .',
#  ' Beer is offered .',
#  ' Waits is offered .',
#  ' Poboy is offered .',
#  ' Raw oysters is offered .',
#  ' Local beer is offered .',
#  ' Crawfish is offered .',
#  ' 15 Dozen Oysters challenge is offered .',
#  ' Coleslaw is offered .',
#  ' Side is offered .',
#  ' Peace maker Po-boy is offered .',
#  ' Menu choices is offered .',
#  ' Acme is offered .',
#  ' Drinks is offered .',
#  ' Oysters is offered .',
#  ' Tables is offered .',
#  ' ACME susnet drink is offered .',
#  ' Bread pudding is offered .',
#  ' Specialty drinks is offered .',
#  ' People watching spot is offered .',
#  ' Buffallo style hot sauce is offered .',
#  ' Line is offered .',
#  ' Long waiting list is a negative review .',
#  ' Sandy mud on the shell is a negative review .',
#  " Don't split checks is a negative review .",
#  ' Only use 3 cards for credit card payments is a negative review .',
#  ' Service reviews are mostly positive .',
#  ' Wait time is not too long .',
#  ' Staff is friendly and helpful .',
#  ' Experience is enjoyable .',
#  ' Wait time can be too long .',
#  ' Staff can be not attentive .',
#  ' Payment is limited to 3 cards .',
#  ' Prices are generally reasonable and fair .',
#  ' Prices are the same as other restaurants .',
#  ' Prices are relatively cheap or inexpensive .',
#  ' Beer is expensive or overpriced .',
#  ' Grilled oysters is expensive or overpriced .',
#  ' 1/2 and 1/2 seafood platter is expensive or overpriced .',
#  ' Add-ons are charged for .']

# %%
compute_faithfulness(reviews, summary_split, 0.2)
# Out:
# summary:  Oysters are of good quality .
# support: 62
# =====
# summary:  Bloody Marys are of good quality .
# support: 24
# =====
# summary:  Fresh oysters are of good quality .
# support: 24
# =====
# summary:  Chargrilled oysters are of good quality .
# support: 38
# =====
# summary:  Bread and butter is of good quality .
# support: 16
# =====
# summary:  Crawfish puppies are of good quality .
# support: 4
# =====
# summary:  Fried seafood is mediocre to horrible .
# support: 0
# =====
# summary:  Gumbo has too much salt .
# support: 4
# =====
# summary:  Staff is praised .
# support: 36
# =====
# summary:  Service is praised .
# support: 61
# =====
# summary:  Atmosphere is praised .
# support: 23
# =====
# summary:  Wait is worth it .
# support: 64
# =====
# summary:  Roscoe and Brandon are friendly .
# support: 5
# =====
# summary:  Restaurant is a must-visit .
# support: 37
# =====
# summary:  Wait can be long .
# support: 68
# =====
# summary:  Service can be spotty .
# support: 28
# =====
# summary:  Variety of style options is offered .
# support: 32
# =====
# summary:  15 Dozen Club is offered .
# support: 1
# =====
# summary:  Soft shell crab is offered .
# support: 11
# =====
# summary:  1/2 and 1/2 is offered .
# support: 5
# =====
# summary:  Beer on tap is offered .
# support: 1
# =====
# summary:  Oyster bar is offered .
# support: 34
# =====
# summary:  Splitting checks is offered .
# support: 0
# =====
# summary:  Splitting credit card payments is offered .
# support: 0
# =====
# summary:  Oysters are offered .
# support: 96
# =====
# summary:  Atmosphere is offered .
# support: 17
# =====
# summary:  Dress is offered .
# support: 0
# =====
# summary:  Reservation is offered .
# support: 11
# =====
# summary:  Food is offered .
# support: 179
# =====
# summary:  Wait times are offered .
# support: 79
# =====
# summary:  Grab a beer is offered .
# support: 8
# =====
# summary:  Sampler plate is offered .
# support: 4
# =====
# summary:  PO boy is offered .
# support: 22
# =====
# summary:  Draft beer is offered .
# support: 1
# =====
# summary:  Char-grilled oysters are offered .
# support: 78
# =====
# summary:  Crawfish is offered .
# support: 15
# =====
# summary:  Po'boy is offered .
# support: 24
# =====
# summary:  Gumbo is offered .
# support: 21
# =====
# summary:  Local IPAs is offered .
# support: 1
# =====
# summary:  Bar is offered .
# support: 25
# =====
# summary:  Cocktails is offered .
# support: 7
# =====
# summary:  Lettuce is offered .
# support: 1
# =====
# summary:  Fried food is offered .
# support: 43
# =====
# summary:  Salad is offered .
# support: 3
# =====
# summary:  Payment is offered .
# support: 20
# =====
# summary:  Seat at the bar is offered .
# support: 24
# =====
# summary:  Beer is offered .
# support: 9
# =====
# summary:  Waits is offered .
# support: 33
# =====
# summary:  Poboy is offered .
# support: 22
# =====
# summary:  Raw oysters is offered .
# support: 13
# =====
# summary:  Local beer is offered .
# support: 1
# =====
# summary:  Crawfish is offered .
# support: 15
# =====
# summary:  15 Dozen Oysters challenge is offered .
# support: 1
# =====
# summary:  Coleslaw is offered .
# support: 1
# =====
# summary:  Side is offered .
# support: 15
# =====
# summary:  Peace maker Po-boy is offered .
# support: 7
# =====
# summary:  Menu choices is offered .
# support: 36
# =====
# summary:  Acme is offered .
# support: 14
# =====
# summary:  Drinks is offered .
# support: 36
# =====
# summary:  Oysters is offered .
# support: 85
# =====
# summary:  Tables is offered .
# support: 6
# =====
# summary:  ACME susnet drink is offered .
# support: 1
# =====
# summary:  Bread pudding is offered .
# support: 2
# =====
# summary:  Specialty drinks is offered .
# support: 14
# =====
# summary:  People watching spot is offered .
# support: 2
# =====
# summary:  Buffallo style hot sauce is offered .
# support: 1
# =====
# summary:  Line is offered .
# support: 21
# =====
# summary:  Long waiting list is a negative review .
# support: 2
# =====
# summary:  Sandy mud on the shell is a negative review .
# support: 2
# =====
# summary:  Don't split checks is a negative review .
# support: 2
# =====
# summary:  Only use 3 cards for credit card payments is a negative review .
# support: 1
# =====
# summary:  Service reviews are mostly positive .
# support: 9
# =====
# summary:  Wait time is not too long .
# support: 51
# =====
# summary:  Staff is friendly and helpful .
# support: 36
# =====
# summary:  Experience is enjoyable .
# support: 107
# =====
# summary:  Wait time can be too long .
# support: 45
# =====
# summary:  Staff can be not attentive .
# support: 21
# =====
# summary:  Payment is limited to 3 cards .
# support: 3
# =====
# summary:  Prices are generally reasonable and fair .
# support: 5
# =====
# summary:  Prices are the same as other restaurants .
# support: 2
# =====
# summary:  Prices are relatively cheap or inexpensive .
# support: 7
# =====
# summary:  Beer is expensive or overpriced .
# support: 0
# =====
# summary:  Grilled oysters is expensive or overpriced .
# support: 2
# =====
# summary:  1/2 and 1/2 seafood platter is expensive or overpriced .
# support: 0
# =====
# summary:  Add-ons are charged for .
# support: 9
# =====
# faithfulness: 22.305882352941175
# 22.305882352941175

# %%
compute_factuality(reviews, summary_split)
# Out:
# summary:  Oysters are of good quality .
# top score: 0.921905517578125
# =====
# summary:  Bloody Marys are of good quality .
# top score: 0.530029296875
# =====
# summary:  Fresh oysters are of good quality .
# top score: 0.8274078369140625
# =====
# summary:  Chargrilled oysters are of good quality .
# top score: 0.872955322265625
# =====
# summary:  Bread and butter is of good quality .
# top score: 0.5555419921875
# =====
# summary:  Crawfish puppies are of good quality .
# top score: 0.56884765625
# =====
# summary:  Fried seafood is mediocre to horrible .
# top score: 0
# =====
# summary:  Gumbo has too much salt .
# top score: 0.616943359375
# =====
# summary:  Staff is praised .
# top score: 0.78240966796875
# =====
# summary:  Service is praised .
# top score: 0.942138671875
# =====
# summary:  Atmosphere is praised .
# top score: 0.9144363403320312
# =====
# summary:  Wait is worth it .
# top score: 0.947174072265625
# =====
# summary:  Roscoe and Brandon are friendly .
# top score: 0.41455078125
# =====
# summary:  Restaurant is a must-visit .
# top score: 0.9529266357421875
# =====
# summary:  Wait can be long .
# top score: 0.9608612060546875
# =====
# summary:  Service can be spotty .
# top score: 0.88165283203125
# =====
# summary:  Variety of style options is offered .
# top score: 0.6986083984375
# =====
# summary:  15 Dozen Club is offered .
# top score: 0.31689453125
# =====
# summary:  Soft shell crab is offered .
# top score: 0.82470703125
# =====
# summary:  1/2 and 1/2 is offered .
# top score: 0.4853515625
# =====
# summary:  Beer on tap is offered .
# top score: 0.7574462890625
# =====
# summary:  Oyster bar is offered .
# top score: 0.6964111328125
# =====
# summary:  Splitting checks is offered .
# top score: 0.0804443359375
# =====
# summary:  Splitting credit card payments is offered .
# top score: 0.107177734375
# =====
# summary:  Oysters are offered .
# top score: 0.938018798828125
# =====
# summary:  Atmosphere is offered .
# top score: 0.815673828125
# =====
# summary:  Dress is offered .
# top score: 0.033203125
# =====
# summary:  Reservation is offered .
# top score: 0.5400390625
# =====
# summary:  Food is offered .
# top score: 0.906524658203125
# =====
# summary:  Wait times are offered .
# top score: 0.7978515625
# =====
# summary:  Grab a beer is offered .
# top score: 0.6162109375
# =====
# summary:  Sampler plate is offered .
# top score: 0.8109130859375
# =====
# summary:  PO boy is offered .
# top score: 0.89544677734375
# =====
# summary:  Draft beer is offered .
# top score: 0.7938232421875
# =====
# summary:  Char-grilled oysters are offered .
# top score: 0.92669677734375
# =====
# summary:  Crawfish is offered .
# top score: 0.7021484375
# =====
# summary:  Po'boy is offered .
# top score: 0.832550048828125
# =====
# summary:  Gumbo is offered .
# top score: 0.9352264404296875
# =====
# summary:  Local IPAs is offered .
# top score: 0.6075439453125
# =====
# summary:  Bar is offered .
# top score: 0.7506103515625
# =====
# summary:  Cocktails is offered .
# top score: 0.7071533203125
# =====
# summary:  Lettuce is offered .
# top score: 0.370361328125
# =====
# summary:  Fried food is offered .
# top score: 0.80963134765625
# =====
# summary:  Salad is offered .
# top score: 0.535400390625
# =====
# summary:  Payment is offered .
# top score: 0.54541015625
# =====
# summary:  Seat at the bar is offered .
# top score: 0.85430908203125
# =====
# summary:  Beer is offered .
# top score: 0.9243927001953125
# =====
# summary:  Waits is offered .
# top score: 0.736083984375
# =====
# summary:  Poboy is offered .
# top score: 0.84375
# =====
# summary:  Raw oysters is offered .
# top score: 0.900787353515625
# =====
# summary:  Local beer is offered .
# top score: 0.30810546875
# =====
# summary:  Crawfish is offered .
# top score: 0.7021484375
# =====
# summary:  15 Dozen Oysters challenge is offered .
# top score: 0.690185546875
# =====
# summary:  Coleslaw is offered .
# top score: 0.33447265625
# =====
# summary:  Side is offered .
# top score: 0.439453125
# =====
# summary:  Peace maker Po-boy is offered .
# top score: 0.8116455078125
# =====
# summary:  Menu choices is offered .
# top score: 0.7479248046875
# =====
# summary:  Acme is offered .
# top score: 0.6492919921875
# =====
# summary:  Drinks is offered .
# top score: 0.8447265625
# =====
# summary:  Oysters is offered .
# top score: 0.90142822265625
# =====
# summary:  Tables is offered .
# top score: 0.351806640625
# =====
# summary:  ACME susnet drink is offered .
# top score: 0.28076171875
# =====
# summary:  Bread pudding is offered .
# top score: 0.34228515625
# =====
# summary:  Specialty drinks is offered .
# top score: 0.66015625
# =====
# summary:  People watching spot is offered .
# top score: 0.6697998046875
# =====
# summary:  Buffallo style hot sauce is offered .
# top score: 0.85772705078125
# =====
# summary:  Line is offered .
# top score: 0.3388671875
# =====
# summary:  Long waiting list is a negative review .
# top score: 0.776153564453125
# =====
# summary:  Sandy mud on the shell is a negative review .
# top score: 0.255859375
# =====
# summary:  Don't split checks is a negative review .
# top score: 0.63702392578125
# =====
# summary:  Only use 3 cards for credit card payments is a negative review .
# top score: 0.739776611328125
# =====
# summary:  Service reviews are mostly positive .
# top score: 0.741455078125
# =====
# summary:  Wait time is not too long .
# top score: 0.919891357421875
# =====
# summary:  Staff is friendly and helpful .
# top score: 0.92156982421875
# =====
# summary:  Experience is enjoyable .
# top score: 0.919464111328125
# =====
# summary:  Wait time can be too long .
# top score: 0.89459228515625
# =====
# summary:  Staff can be not attentive .
# top score: 0.7255859375
# =====
# summary:  Payment is limited to 3 cards .
# top score: 0.9475173950195312
# =====
# summary:  Prices are generally reasonable and fair .
# top score: 0.8303375244140625
# =====
# summary:  Prices are the same as other restaurants .
# top score: 0.9515380859375
# =====
# summary:  Prices are relatively cheap or inexpensive .
# top score: 0.7027435302734375
# =====
# summary:  Beer is expensive or overpriced .
# top score: 0.087158203125
# =====
# summary:  Grilled oysters is expensive or overpriced .
# top score: 0.326904296875
# =====
# summary:  1/2 and 1/2 seafood platter is expensive or overpriced .
# top score: 0.08203125
# =====
# summary:  Add-ons are charged for .
# top score: 0.685791015625
# =====
# factuality: 0.6689736758961397
# 0.6689736758961397

# %%
compute_genericity(reviews_rest_concat, summary_split)
# Out:
# word in summary: oysters
# count: 8
# =====
# word in summary: good
# count: 99
# =====
# word in summary: quality
# count: 45
# =====
# word in summary: bloody
# count: 2
# =====
# word in summary: marys
# count: 0
# =====
# word in summary: good
# count: 99
# =====
# word in summary: quality
# count: 45
# =====
# word in summary: fresh
# count: 61
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: good
# count: 99
# =====
# word in summary: quality
# count: 45
# =====
# word in summary: chargrilled
# count: 0
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: good
# count: 99
# =====
# word in summary: quality
# count: 45
# =====
# word in summary: bread
# count: 36
# =====
# word in summary: butter
# count: 16
# =====
# word in summary: good
# count: 99
# =====
# word in summary: quality
# count: 45
# =====
# word in summary: crawfish
# count: 2
# =====
# word in summary: puppies
# count: 2
# =====
# word in summary: good
# count: 99
# =====
# word in summary: quality
# count: 45
# =====
# word in summary: fried
# count: 36
# =====
# word in summary: seafood
# count: 16
# =====
# word in summary: mediocre
# count: 11
# =====
# word in summary: horrible
# count: 10
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: much
# count: 67
# =====
# word in summary: salt
# count: 15
# =====
# word in summary: staff
# count: 76
# =====
# word in summary: praised
# count: 0
# =====
# word in summary: service
# count: 91
# =====
# word in summary: praised
# count: 0
# =====
# word in summary: atmosphere
# count: 36
# =====
# word in summary: praised
# count: 0
# =====
# word in summary: wait
# count: 80
# =====
# word in summary: worth
# count: 47
# =====
# word in summary: roscoe
# count: 0
# =====
# word in summary: brandon
# count: 0
# =====
# word in summary: friendly
# count: 78
# =====
# word in summary: restaurant
# count: 73
# =====
# word in summary: must-visit
# count: 1
# =====
# word in summary: wait
# count: 80
# =====
# word in summary: long
# count: 58
# =====
# word in summary: service
# count: 91
# =====
# word in summary: spotty
# count: 0
# =====
# word in summary: variety
# count: 21
# =====
# word in summary: style
# count: 28
# =====
# word in summary: options
# count: 32
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: 15
# count: 26
# =====
# word in summary: dozen
# count: 7
# =====
# word in summary: club
# count: 5
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: soft
# count: 17
# =====
# word in summary: shell
# count: 8
# =====
# word in summary: crab
# count: 18
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: 1/2
# count: 9
# =====
# word in summary: 1/2
# count: 9
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: beer
# count: 36
# =====
# word in summary: tap
# count: 14
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: oyster
# count: 8
# =====
# word in summary: bar
# count: 57
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: splitting
# count: 3
# =====
# word in summary: checks
# count: 4
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: splitting
# count: 3
# =====
# word in summary: credit
# count: 7
# =====
# word in summary: card
# count: 13
# =====
# word in summary: payments
# count: 0
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: atmosphere
# count: 36
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: dress
# count: 18
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: reservation
# count: 15
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: food
# count: 94
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: wait
# count: 80
# =====
# word in summary: times
# count: 61
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: grab
# count: 25
# =====
# word in summary: beer
# count: 36
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: sampler
# count: 4
# =====
# word in summary: plate
# count: 35
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: po
# count: 100
# =====
# word in summary: boy
# count: 24
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: draft
# count: 4
# =====
# word in summary: beer
# count: 36
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: char-grilled
# count: 0
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: crawfish
# count: 2
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: po'boy
# count: 1
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: local
# count: 33
# =====
# word in summary: ipas
# count: 1
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: bar
# count: 57
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: cocktails
# count: 10
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: lettuce
# count: 12
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: fried
# count: 36
# =====
# word in summary: food
# count: 94
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: salad
# count: 50
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: payment
# count: 2
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: seat
# count: 50
# =====
# word in summary: bar
# count: 57
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: beer
# count: 36
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: waits
# count: 6
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: poboy
# count: 2
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: raw
# count: 27
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: local
# count: 33
# =====
# word in summary: beer
# count: 36
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: crawfish
# count: 2
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: 15
# count: 26
# =====
# word in summary: dozen
# count: 7
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: challenge
# count: 2
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: coleslaw
# count: 8
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: side
# count: 80
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: peace
# count: 2
# =====
# word in summary: maker
# count: 1
# =====
# word in summary: po-boy
# count: 4
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: menu
# count: 64
# =====
# word in summary: choices
# count: 10
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: drinks
# count: 33
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: tables
# count: 39
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: susnet
# count: 0
# =====
# word in summary: drink
# count: 48
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: bread
# count: 36
# =====
# word in summary: pudding
# count: 3
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: specialty
# count: 4
# =====
# word in summary: drinks
# count: 33
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: people
# count: 69
# =====
# word in summary: watching
# count: 9
# =====
# word in summary: spot
# count: 42
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: buffallo
# count: 0
# =====
# word in summary: style
# count: 28
# =====
# word in summary: hot
# count: 53
# =====
# word in summary: sauce
# count: 54
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: line
# count: 37
# =====
# word in summary: offered
# count: 15
# =====
# word in summary: long
# count: 58
# =====
# word in summary: waiting
# count: 28
# =====
# word in summary: list
# count: 28
# =====
# word in summary: negative
# count: 5
# =====
# word in summary: review
# count: 54
# =====
# word in summary: sandy
# count: 0
# =====
# word in summary: mud
# count: 0
# =====
# word in summary: shell
# count: 8
# =====
# word in summary: negative
# count: 5
# =====
# word in summary: review
# count: 54
# =====
# word in summary: don't
# count: 72
# =====
# word in summary: split
# count: 11
# =====
# word in summary: checks
# count: 4
# =====
# word in summary: negative
# count: 5
# =====
# word in summary: review
# count: 54
# =====
# word in summary: only
# count: 76
# =====
# word in summary: use
# count: 87
# =====
# word in summary: 3
# count: 74
# =====
# word in summary: cards
# count: 3
# =====
# word in summary: credit
# count: 7
# =====
# word in summary: card
# count: 13
# =====
# word in summary: payments
# count: 0
# =====
# word in summary: negative
# count: 5
# =====
# word in summary: review
# count: 54
# =====
# word in summary: service
# count: 91
# =====
# word in summary: reviews
# count: 30
# =====
# word in summary: mostly
# count: 11
# =====
# word in summary: positive
# count: 7
# =====
# word in summary: wait
# count: 80
# =====
# word in summary: time
# count: 95
# =====
# word in summary: long
# count: 58
# =====
# word in summary: staff
# count: 76
# =====
# word in summary: friendly
# count: 78
# =====
# word in summary: helpful
# count: 22
# =====
# word in summary: experience
# count: 64
# =====
# word in summary: enjoyable
# count: 7
# =====
# word in summary: wait
# count: 80
# =====
# word in summary: time
# count: 95
# =====
# word in summary: long
# count: 58
# =====
# word in summary: staff
# count: 76
# =====
# word in summary: attentive
# count: 29
# =====
# word in summary: payment
# count: 2
# =====
# word in summary: limited
# count: 12
# =====
# word in summary: 3
# count: 74
# =====
# word in summary: cards
# count: 3
# =====
# word in summary: prices
# count: 41
# =====
# word in summary: generally
# count: 3
# =====
# word in summary: reasonable
# count: 21
# =====
# word in summary: fair
# count: 17
# =====
# word in summary: prices
# count: 41
# =====
# word in summary: restaurants
# count: 26
# =====
# word in summary: prices
# count: 41
# =====
# word in summary: relatively
# count: 3
# =====
# word in summary: cheap
# count: 17
# =====
# word in summary: inexpensive
# count: 7
# =====
# word in summary: beer
# count: 36
# =====
# word in summary: expensive
# count: 22
# =====
# word in summary: overpriced
# count: 5
# =====
# word in summary: grilled
# count: 18
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: expensive
# count: 22
# =====
# word in summary: overpriced
# count: 5
# =====
# word in summary: 1/2
# count: 9
# =====
# word in summary: 1/2
# count: 9
# =====
# word in summary: seafood
# count: 16
# =====
# word in summary: platter
# count: 8
# =====
# word in summary: expensive
# count: 22
# =====
# word in summary: overpriced
# count: 5
# =====
# word in summary: add-ons
# count: 0
# =====
# word in summary: charged
# count: 6
# =====
# genericity: 14.896027970748834
# 14.896027970748834

# %%
summary_file = 'yelp_summary_aspect_review+acos'
with open(summary_file, 'r') as f:
    summary = f.read()
summary_split = split_and_rephrase(summary).split('\n')
summary_split = [x for x in summary_split if len(x) > 0]

# %%
summary_split
# Out:
# ['The oysters are delicious .',
#  'The oysters are crispy .',
#  'The oysters have a smoky flavor .',
#  'The taste, texture, and flavor of the oysters are enjoyed .',
#  'The food is awesome .',
#  'The food is great .',
#  'The food is amazing .',
#  'The food is well-seasoned .',
#  'The food is not the best .',
#  'The food is meh .',
#  'Acme is highly recommended .',
#  'Acme has great quality and style options .',
#  'Acme has great seafood .',
#  'Acme has New Orleans cuisine .',
#  'Acme is worth the wait .',
#  'Acme is a favorite among customers .',
#  'Acme is the best .',
#  'Acme has long waits .',
#  'Acme is busy .',
#  'Acme is touristy .',
#  'Acme is a tourist trap .',
#  'The gumbo is very tasty .',
#  'The gumbo is great .',
#  'The gumbo is delicious .',
#  "The gumbo is bowl-lickin' good .",
#  'The gumbo is pretty good .',
#  'The gumbo stood out .',
#  'The gumbo is very good .',
#  'The gumbo is good .',
#  'The gumbo is too salty .',
#  'The gumbo is not really edible .',
#  'The staff is friendly .']

# %%
compute_faithfulness(reviews, summary_split, 0.2)
# Out:
# summary: The oysters are delicious .
# support: 52
# =====
# summary: The oysters are crispy .
# support: 5
# =====
# summary: The oysters have a smoky flavor .
# support: 38
# =====
# summary: The taste, texture, and flavor of the oysters are enjoyed .
# support: 13
# =====
# summary: The food is awesome .
# support: 96
# =====
# summary: The food is great .
# support: 107
# =====
# summary: The food is amazing .
# support: 88
# =====
# summary: The food is well-seasoned .
# support: 20
# =====
# summary: The food is not the best .
# support: 19
# =====
# summary: The food is meh .
# support: 4
# =====
# summary: Acme is highly recommended .
# support: 42
# =====
# summary: Acme has great quality and style options .
# support: 2
# =====
# summary: Acme has great seafood .
# support: 72
# =====
# summary: Acme has New Orleans cuisine .
# support: 6
# =====
# summary: Acme is worth the wait .
# support: 61
# =====
# summary: Acme is a favorite among customers .
# support: 7
# =====
# summary: Acme is the best .
# support: 15
# =====
# summary: Acme has long waits .
# support: 56
# =====
# summary: Acme is busy .
# support: 48
# =====
# summary: Acme is touristy .
# support: 18
# =====
# summary: Acme is a tourist trap .
# support: 9
# =====
# summary: The gumbo is very tasty .
# support: 17
# =====
# summary: The gumbo is great .
# support: 16
# =====
# summary: The gumbo is delicious .
# support: 16
# =====
# summary: The gumbo is bowl-lickin' good .
# support: 4
# =====
# summary: The gumbo is pretty good .
# support: 21
# =====
# summary: The gumbo stood out .
# support: 15
# =====
# summary: The gumbo is very good .
# support: 22
# =====
# summary: The gumbo is good .
# support: 19
# =====
# summary: The gumbo is too salty .
# support: 2
# =====
# summary: The gumbo is not really edible .
# support: 3
# =====
# summary: The staff is friendly .
# support: 32
# =====
# faithfulness: 29.53125
# 29.53125

# %%
compute_factuality(reviews, summary_split)
# Out:
# summary: The oysters are delicious .
# top score: 0.9493370056152344
# =====
# summary: The oysters are crispy .
# top score: 0.7845458984375
# =====
# summary: The oysters have a smoky flavor .
# top score: 0.794464111328125
# =====
# summary: The taste, texture, and flavor of the oysters are enjoyed .
# top score: 0.426605224609375
# =====
# summary: The food is awesome .
# top score: 0.9821052551269531
# =====
# summary: The food is great .
# top score: 0.9783859252929688
# =====
# summary: The food is amazing .
# top score: 0.9808464050292969
# =====
# summary: The food is well-seasoned .
# top score: 0.97918701171875
# =====
# summary: The food is not the best .
# top score: 0.9802112579345703
# =====
# summary: The food is meh .
# top score: 0.888031005859375
# =====
# summary: Acme is highly recommended .
# top score: 0.93353271484375
# =====
# summary: Acme has great quality and style options .
# top score: 0.570068359375
# =====
# summary: Acme has great seafood .
# top score: 0.9760513305664062
# =====
# summary: Acme has New Orleans cuisine .
# top score: 0.556060791015625
# =====
# summary: Acme is worth the wait .
# top score: 0.9254913330078125
# =====
# summary: Acme is a favorite among customers .
# top score: 0.46743011474609375
# =====
# summary: Acme is the best .
# top score: 0.88336181640625
# =====
# summary: Acme has long waits .
# top score: 0.9139404296875
# =====
# summary: Acme is busy .
# top score: 0.8480224609375
# =====
# summary: Acme is touristy .
# top score: 0.852020263671875
# =====
# summary: Acme is a tourist trap .
# top score: 0.794189453125
# =====
# summary: The gumbo is very tasty .
# top score: 0.931396484375
# =====
# summary: The gumbo is great .
# top score: 0.9417266845703125
# =====
# summary: The gumbo is delicious .
# top score: 0.8626708984375
# =====
# summary: The gumbo is bowl-lickin' good .
# top score: 0.8408203125
# =====
# summary: The gumbo is pretty good .
# top score: 0.9150009155273438
# =====
# summary: The gumbo stood out .
# top score: 0.80889892578125
# =====
# summary: The gumbo is very good .
# top score: 0.9177627563476562
# =====
# summary: The gumbo is good .
# top score: 0.960113525390625
# =====
# summary: The gumbo is too salty .
# top score: 0.551513671875
# =====
# summary: The gumbo is not really edible .
# top score: 0.3701171875
# =====
# summary: The staff is friendly .
# top score: 0.9826583862304688
# =====
# factuality: 0.8295802474021912
# 0.8295802474021912

# %%
compute_genericity(reviews_rest_concat, summary_split)
# Out:
# word in summary: the
# count: 100
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: delicious
# count: 74
# =====
# word in summary: the
# count: 100
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: crispy
# count: 12
# =====
# word in summary: the
# count: 100
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: smoky
# count: 4
# =====
# word in summary: flavor
# count: 64
# =====
# word in summary: the
# count: 100
# =====
# word in summary: taste,
# count: 2
# =====
# word in summary: texture,
# count: 1
# =====
# word in summary: flavor
# count: 64
# =====
# word in summary: oysters
# count: 8
# =====
# word in summary: enjoyed
# count: 39
# =====
# word in summary: the
# count: 100
# =====
# word in summary: food
# count: 94
# =====
# word in summary: awesome
# count: 45
# =====
# word in summary: the
# count: 100
# =====
# word in summary: food
# count: 94
# =====
# word in summary: great
# count: 91
# =====
# word in summary: the
# count: 100
# =====
# word in summary: food
# count: 94
# =====
# word in summary: amazing
# count: 58
# =====
# word in summary: the
# count: 100
# =====
# word in summary: food
# count: 94
# =====
# word in summary: well-seasoned
# count: 0
# =====
# word in summary: the
# count: 100
# =====
# word in summary: food
# count: 94
# =====
# word in summary: best
# count: 76
# =====
# word in summary: the
# count: 100
# =====
# word in summary: food
# count: 94
# =====
# word in summary: meh
# count: 9
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: highly
# count: 22
# =====
# word in summary: recommended
# count: 11
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: great
# count: 91
# =====
# word in summary: quality
# count: 45
# =====
# word in summary: style
# count: 28
# =====
# word in summary: options
# count: 32
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: great
# count: 91
# =====
# word in summary: seafood
# count: 16
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: new
# count: 55
# =====
# word in summary: orleans
# count: 0
# =====
# word in summary: cuisine
# count: 8
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: worth
# count: 47
# =====
# word in summary: wait
# count: 80
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: favorite
# count: 53
# =====
# word in summary: among
# count: 6
# =====
# word in summary: customers
# count: 23
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: best
# count: 76
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: long
# count: 58
# =====
# word in summary: waits
# count: 6
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: busy
# count: 36
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: touristy
# count: 1
# =====
# word in summary: acme
# count: 0
# =====
# word in summary: tourist
# count: 3
# =====
# word in summary: trap
# count: 2
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: tasty
# count: 39
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: great
# count: 91
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: delicious
# count: 74
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: bowl-lickin'
# count: 0
# =====
# word in summary: good
# count: 99
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: pretty
# count: 55
# =====
# word in summary: good
# count: 99
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: stood
# count: 5
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: good
# count: 99
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: good
# count: 99
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: salty
# count: 7
# =====
# word in summary: the
# count: 100
# =====
# word in summary: gumbo
# count: 2
# =====
# word in summary: really
# count: 81
# =====
# word in summary: edible
# count: 15
# =====
# word in summary: the
# count: 100
# =====
# word in summary: staff
# count: 76
# =====
# word in summary: friendly
# count: 78
# =====
# genericity: 20.99237481490993
# 20.99237481490993
